# %%
#1
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\mamid\OneDrive\Desktop\MACHINE LEARNING LAB\extracted_features_charrec.csv")
soil_data = df['12']
water_data = df['30']
 
# Scatter plot
plt.scatter(soil_data, water_data, alpha=0.8)
plt.title('Scatter Plot of Soil vs Water')
plt.xlabel('Soil')
plt.ylabel('Water')
plt.show()

# %%
#2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
df = pd.read_csv(r"C:\Users\mamid\OneDrive\Desktop\MACHINE LEARNING LAB\extracted_features_charrec.csv")
X = df[['0']]
y = df['3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=22)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Coefficient: {model.coef_[0]:.2f}')
print(f'Intercept: {model.intercept_:.2f}')
print(f'Mean Squared Error: {mse:.2f}')
# Out:
# Coefficient: -0.02
# Intercept: 0.02
# Mean Squared Error: 0.02
